# %%
    from sklearn.neural_network import MLPClassifier
import nltk
import string
from datasets import load_dataset
import re
from nltk.corpus import stopwords
from nltk import pos_tag
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import mlflow
from sklearnex import patch_sklearn
from warnings import filterwarnings
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/uxlfoundation/scikit-learn-intelex)

# %%
filterwarnings("ignore")

# %%
imdb_dataset = load_dataset("imdb")
stop_words = set(stopwords.words("english"))

# %%
#text_preprocess_types = [None, 'стемминг', 'лемматизация']
text_preprocess_types = ['None']

#words_classes = ['N', 'NJ', 'NJV', 'ALL']
words_classes = ['ALL']

#frequency_filtration_types = [None, 'low', 'high', 'both']
frequency_filtration_types = [None, 'low']

n_components = [750, 1000, 1250, 1500]

hidden_layer_size = [150, 200, 250]

iterations = [10, 20, 30]

# %%
combinations = len(text_preprocess_types) * len(words_classes) * len(frequency_filtration_types) * len(hidden_layer_size) * len(n_components)
print(combinations)
# Out:
# 32

# %%
def base_ag_news_preprocess(text):
    tokens = text.lower()

    # Удаление спец слов
    special_words = ['<br /><br />'] # можно обработать римские цифры, удалить film, movie, ...
    for word in special_words:
        tokens = tokens.replace(word, '')
    
    # Удаление пунктуации и цифр
    #tokens = ''.join(i if i not in set(string.punctuation) - set('-') | set(string.digits) else ' ' for i in tokens)
    tokens = ''.join(i if i not in set(string.punctuation)  | set(string.digits) else ' ' for i in tokens)
    
    # Токенизация
    tokens = nltk.word_tokenize(tokens)
    
    # Удаление стоп слов
    stop_wordsL = stop_words - {'no','not'}
    #stop_wordsL = stop_words
    tokens = [word for word in tokens if (word not in stop_wordsL and word != '-')]
    return tokens

# %%
def different_ag_news_preprocess(tokens, preprocess_type, words_class):
    
    # Обработка слов
    if preprocess_type == 'лемматизация':
        lemmatizer = nltk.WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
    elif preprocess_type == 'стемминг':
        stemmer = nltk.PorterStemmer()
        tokens = [stemmer.stem(token) for token in tokens]
    
    # Обработка частей речи
    tokens = pos_tag(tokens)
    if words_class == 'N':
        tokens = [word for word, tag in tokens if tag.startswith('N')]
    elif words_class == 'NJ':
        tokens = [word for word, tag in tokens if tag.startswith('N') or tag.startswith('J')]
    elif words_class == 'NJV':
        tokens = [word for word, tag in tokens if tag.startswith('N') or tag.startswith('J') or tag.startswith('V')]
    elif words_class == 'ALL':
        tokens = [word for word, _ in tokens]
    
    return tokens

# %%
def frequency_filtration(words_dictionary, frequency_filtration_type):
    if frequency_filtration_type == 'low':
        return dict([(key, value) for key, value in words_dictionary.items() if value >= 10 ])
    elif frequency_filtration_type == 'high':
        return dict([(key, value) for key, value in words_dictionary.items() if value <= 3000])
    elif frequency_filtration_type == 'both':
        return dict([(key, value) for key, value in words_dictionary.items() if 10 <= value <= 3000])
    else:
        return words_dictionary

# %%
def dummy(doc):
    return doc

# %%
def final_ag_news_preprocess(dataset, model_type):
    # Подготовка данных
    x_train = dataset['train']['text']
    y_train = dataset['train']['label']
    
    x_test = dataset['test']['text']
    y_test = dataset['test']['label']
    
    # Базовая обработка
    for i, text in enumerate(x_train):
        x_train[i] = base_ag_news_preprocess(text)
        
    for i, text in enumerate(x_test):
        x_test[i] = base_ag_news_preprocess(text)
    
    index = 0
    # Вариативная обработка
    for preprocess_type in text_preprocess_types: 
        for words_class in words_classes:         
            words = {}
            xtr = x_train
            xte = x_test
            
            # Обработка текстов
            for i, tokens in enumerate(xtr):
                final_tokens = different_ag_news_preprocess(tokens, preprocess_type, words_class)
                xtr[i] = final_tokens
                
                # Заполнение словаря
                for token in final_tokens:
                    if token not in words:
                        words[token] = 1
                    else:
                        words[token] += 1
            
            xte = [different_ag_news_preprocess(tokens, preprocess_type, words_class) for tokens in xte]
                    
            # Фильтрация по частоте
            for frequency_filtration_type in frequency_filtration_types: 
                filtered_words = frequency_filtration(words, frequency_filtration_type)
                token_length = len(filtered_words)
                
                # Векторизация слов
                word_list = sorted(filtered_words.keys())
                # Присвоение словам индексов
                words_indexed = {}
                for idx, word in enumerate(word_list):
                    words_indexed[word] = idx
                
                # TF-IDF
                vectorizer_TFIDF = TfidfVectorizer(vocabulary=words_indexed, preprocessor=dummy, tokenizer=dummy, dtype=np.float32)
                x_train_TFIDF = vectorizer_TFIDF.fit_transform(xtr)
                x_test_TFIDF = vectorizer_TFIDF.transform(xte)
                
                #LSI
                for n_num in n_components:
                    SVD_TFIDF = TruncatedSVD(n_components=n_num)
                    
                    SVD_TFIDF.fit(x_train_TFIDF)
                    
                    x_train_TFIDF_SVD = SVD_TFIDF.transform(x_train_TFIDF)
                    x_test_TFIDF_SVD = SVD_TFIDF.transform(x_test_TFIDF)

                    # Построение классификаторов
                    for size in hidden_layer_size:
                        for max_iter in iterations:
                            mlp_clf_TFIDF = MLPClassifier(hidden_layer_sizes=(size,), activation='relu', solver='adam', max_iter=max_iter, random_state=42)
                        
                            # Обучение классификаторов
                            mlp_clf_TFIDF.fit(x_train_TFIDF_SVD, y_train)
                            
                            # Тестирование
                            predictions_TFIDF = mlp_clf_TFIDF.predict(x_test_TFIDF_SVD)
                            
                            # Метрики
                            macro_score_TFIDF = f1_score(y_test, predictions_TFIDF, average='macro')
                            
                            mlflow.start_run(run_name=f'{model_type}_{preprocess_type}_{words_class}_{frequency_filtration_type}_{size}_SVD{n_num}_{max_iter}_TFIDF_Ver3')
                            mlflow.log_param('model', mlp_clf_TFIDF.__class__.__name__)
                            mlflow.log_param('preprocess_type', preprocess_type)
                            mlflow.log_param('words_class', words_class)
                            mlflow.log_param('frequency_filtration_type', frequency_filtration_type)
                            mlflow.log_param('token_length', token_length)
                            mlflow.log_param('n_components', n_num)
                            mlflow.log_param('hidden_layer_sizes', size)
                            mlflow.log_param('word vectorizer', 'TFIDF')
                            mlflow.log_param('max_iter', max_iter)
                            #mlflow.sklearn.log_model(clf_SVD, 'ADA(forest)')
                            mlflow.log_metric('macro_score', macro_score_TFIDF)
                            mlflow.end_run()
                            
                            index += 1
                            print(f'Итерация {index} / {combinations}')

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment(experiment_name="IMDB_MLP")
# Out:
# 2025/03/30 10:20:01 INFO mlflow.tracking.fluent: Experiment with name 'IMDB_MLP' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/453469365661828055', creation_time=1743319201970, experiment_id='453469365661828055', last_update_time=1743319201970, lifecycle_stage='active', name='IMDB_MLP', tags={}>

# %%
final_ag_news_preprocess(imdb_dataset, 'MLP')
# Out:
# 🏃 View run MLP_None_ALL_None_150_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/ab8ee95d2c7a449f8448d5903e4af19d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 1 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/9db5aca9e13a402ebd78f4f035fb1520
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 2 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/1a5a3a47e82f439e9871b8756bc12f5f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 3 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/9bbd6419234e419b9a73a3febe7b8b69
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 4 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/03a1df28a42c41e599893227599223f6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 5 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/220b6e31e160404ab48aa8b1a5740a01
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 6 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/94ae56b518ef4316bd539414898fbbb1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 7 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/ed13d15aecd54cd0996b070ce2971dd8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 8 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/dd84582e49fc4a12adbfc8c650969670
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 9 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/3d5b57c54e6943268b54eeda1a3730de
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 10 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/807d894b241d455393090bf8408bd173
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 11 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/1f5857bcc2254dd8b0e8854f7ea3be65
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 12 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/e28f78c258134c3bae088aca46ccf9c9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 13 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/edf9498cc0c14f15a4efba566a09307c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 14 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/b498cabbe975490fabaca4e580c051fd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 15 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/87ae074ef5ba428bb2c21ba39a6b5741
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 16 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/31367525a7484c7483588f3f90058cce
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 17 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/785c0c924e56464d8dc466460885df50
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 18 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/9dfaec53a2c149489ac9e2f5d4374003
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 19 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/14d6d971cce64d5cb6e606c0f7895cb9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 20 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/3f720b62475b4fd6a5d4e181d7fa1dc5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 21 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/b0fe286bb9ff4d048a6be6c55356b6c9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 22 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/44ba6476c91d4ec8b300ecbeb0b0a296
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 23 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/09ef5c2114d54c3ba31bb22681a50e2d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 24 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/7430118ca00641b89a0643d4b29f97fe
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 25 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/57ad71d13c1645a39306db9e0cac6cbe
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 26 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/5bf1f060c4124a7b8dce37b9d5c778ae
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 27 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/97f2628b54354529bb6a6d61b037cbdb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 28 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/d5f2b31b85df49da826b94a24b9c1e27
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 29 / 32
# 🏃 View run MLP_None_ALL_None_150_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/6ff4f4b45a564aa393d5c2b162b69cb8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 30 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/df0dc077ce0e48a881e51b4f30f178bb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 31 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/73b1aa97811f48d0abcee6029e0cccc9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 32 / 32
# 🏃 View run MLP_None_ALL_None_200_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/519eb38fd0504541ae73368418419575
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 33 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/087a8fc92e2344f6842a7248b68b3ce5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 34 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/78eafb45ebac43a29e0881d031169d76
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 35 / 32
# 🏃 View run MLP_None_ALL_None_250_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/85e740cd0d0f4169802e6853ea0effbd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 36 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/457466707f1f4d0ab518f6012d0a395f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 37 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/18a8677398d94214beaf4ab44a0a2851
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 38 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/2d5d438add7041bb834eec1174fed1a9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 39 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/afecaf0eaed44c4aad858e877aab3546
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 40 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/6d6747db1bb7468ab3c47634a947652d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 41 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/f6f083da9ad247d2b0c96ea3a99c82be
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 42 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD750_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/5a9ab916de6d45a78a5c8b58c03f7869
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 43 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD750_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/a867d6d8ac07438aa59d7857b55723fa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 44 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD750_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/eb802f16deb64c549d2056327290181b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 45 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/0358f2a583254cca86603695cf5b8a0f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 46 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/cc8ad721f1e54815a777a8b97716eef9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 47 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/097348afaab64191a2ae837132d50b48
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 48 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/884dfaa405dd47f8be31f5f96912f9fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 49 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/c9a3614d31f14294abf8913d450d5b2c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 50 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/fc788e3979404308805d23c917475d33
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 51 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1000_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/5f444c62763a4176b1369c5ed1153f86
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 52 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1000_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/ea79c38828cd4f479f77fddff90872ec
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 53 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1000_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/027624b7e41c4050a3c4f9a5de066eac
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 54 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/784b84f09d394d858f99c760ff30bcc5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 55 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/d23e2aa6e1404016a110ea4d8613cff7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 56 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/f768bc096d0549e0b5e83fdc66d9c9fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 57 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/5a65bd430b4e42d8a32e3dfba604be0c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 58 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/9eefadf9194a4131b30ed93b320953d3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 59 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/4100983b897d47ef85b007da7d9f07a8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 60 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1250_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/6aa4415f9b4e478db527fd167400fbec
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 61 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1250_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/9af6aab2ff094c6a905e50aee5bd3d56
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 62 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1250_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/3219e0f4de714d3cbd06c3ac90ac85d3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 63 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/65412c41da8d4201bf3ebe4f40c05d60
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 64 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/87d1cf5d5e264f2ca4f0dbe6b06afb06
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 65 / 32
# 🏃 View run MLP_None_ALL_low_150_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/40de9910360d47f6aba1c97c1c3615ad
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 66 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/d22841bebb6949699c9be0757a08c405
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 67 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/41379be26bfa410aaf92dd4a2b1e2005
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 68 / 32
# 🏃 View run MLP_None_ALL_low_200_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/1bdccc84773048e2bc5d6534af7bf68c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 69 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1500_10_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/3670d3db12214cb2a728b25f22b765f0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 70 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1500_20_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/bbcdcbc2254f4fb195b621a0259d0e48
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 71 / 32
# 🏃 View run MLP_None_ALL_low_250_SVD1500_30_TFIDF_Ver3 at: http://127.0.0.1:5000/#/experiments/453469365661828055/runs/7582665867f34d35b77595d7bce94c0a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/453469365661828055
# Итерация 72 / 32

# %% [markdown]
# Ручные тесты

# %%
dataset = ag_news_dataset
preprocess_type = None
words_class = 'NJ'
frequency_filtration_type = None

# Подготовка данных
x_train = dataset['train']['text']
y_train = dataset['train']['label']
    
x_test = dataset['test']['text']
y_test = dataset['test']['label']
    
# Базовая обработка
for i, text in enumerate(x_train):
    x_train[i] = base_ag_news_preprocess(text)
        
for i, text in enumerate(x_test):
    x_test[i] = base_ag_news_preprocess(text)
    
words = {}
xtr = x_train
xte = x_test
            
# Обработка текстов
for i, tokens in enumerate(xtr):
    final_tokens = different_ag_news_preprocess(tokens, preprocess_type, words_class)
    xtr[i] = final_tokens
                
    # Заполнение словаря
    for token in final_tokens:
        if token not in words:
            words[token] = 1
        else:
            words[token] += 1
            
xte = [different_ag_news_preprocess(tokens, preprocess_type, words_class) for tokens in xte]
                    
# Фильтрация по частоте
filtered_words = frequency_filtration(words, frequency_filtration_type)
token_length = len(filtered_words)
                
# Векторизация слов
word_list = sorted(filtered_words.keys())
# Присвоение словам индексов
words_indexed = {}
for idx, word in enumerate(word_list):
    words_indexed[word] = idx
    
# TF-IDF
vectorizer_TFIDF = TfidfVectorizer(vocabulary=words_indexed, preprocessor=dummy, tokenizer=dummy, dtype=np.float32)
x_train_TFIDF = vectorizer_TFIDF.fit_transform(xtr)
x_test_TFIDF = vectorizer_TFIDF.transform(xte)

# %%
SVD = TruncatedSVD(n_components=10, random_state=42)

# %%
SVD.fit(x_train_TFIDF)
# Out:
# TruncatedSVD(n_components=1500, random_state=42)

# %%
x_train_SVD = SVD.transform(x_train_TFIDF)
x_test_SVD = SVD.transform(x_test_TFIDF)

# %%
clf_SVD = MLPClassifier(hidden_layer_sizes=(250,), activation='relu', solver='adam', max_iter=30, random_state=42)
clf_SVD = clf_SVD.fit(x_train_TFIDF, y_train)

# %%
predictions = clf_SVD.predict(x_test_TFIDF)
macro_score = f1_score(y_test, predictions, average='macro')

# %%
print(macro_score)
# Out:
# 0.8909086979348653
